# %% [markdown]
# # Resumen de los datos: dimensiones y estructuras

# %%
import pandas as pd
import os

# %%
main_path="c:/Users/jpolvorinosbarrio/Cursos/python-ml-course/datasets"
filename="titanic/titanic3.csv"
#fullpath=main_path+"/"+filename
fullpath=os.path.join(main_path,filename)
#Mismo fichero pero tomado directamente del github
urldata = "https://raw.githubusercontent.com/joanby/python-ml-course/master/datasets/titanic/titanic3.csv"

# %%
#data = pd. read_csv(fullpath)
data = pd. read_csv(urldata)

# %%
#los primeros registros
data.head(5)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
#Los últimos registros
data.tail(10)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1299       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1301       3         0                     Youseff, Mr. Gerious    male  45.5
# 1302       3         0                        Yousif, Mr. Wazli    male   NaN
# 1303       3         0                    Yousseff, Mr. Gerious    male   NaN
# 1304       3         0                     Zabour, Miss. Hileni  female  14.5
# 1305       3         0                    Zabour, Miss. Thamine  female   NaN
# 1306       3         0                Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                      Zakarian, Mr. Ortin    male  27.0
# 1308       3         0                       Zimmerman, Mr. Leo    male  29.0
#
#       sibsp  parch  ticket     fare cabin embarked boat   body home.dest
# ...

# %%
#dimension número de (filas y columnas)
data.shape
# Out:
# (1309, 14)

# %%
#Nombre de las columnas
data.columns.values
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %% [markdown]
# ### Vamos a hacer un resumen de los estadisticos básicos variables numéricas

# %%
#Estadisticos básicos.
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
# count - NÚMERO DE OBJETOS: objetos que hay no nulos por ejemplo body = 121 quiere decir que se encontraron 121 cuerpos
# mean -  PROMEDIO : 
# std -   DESVIACIÓN ESTANDAR : Desviación estandar. Como se desvían los valores con respecto al valor centrarl que es la media
# min -   VALOR MÍNIMO
# 25% -   PERCENTILES 25%
# 50% -   PERCENTILES 50%
# 75% -   PERCENTILES 75%
# max -  VALOR MÁXIMO

# %%
#tipo de datos
data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# ## Missing Values

# %%
pd.isnull(data["body"])
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1304    False
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# Name: body, Length: 1309, dtype: bool

# %%
pd.notnull(data["body"])
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1304     True
# 1305    False
# 1306     True
# 1307    False
# 1308    False
# Name: body, Length: 1309, dtype: bool

# %%
#Numero de los valores nulos de la columna body. Se utiliza la suma ya que True es 1 y False es 0.
pd.isnull(data["body"]).values.ravel().sum()
# Out:
# 1188

# %%
# En este caso contabilizamos los que no son nulos y nos salen 121 que son los que salen en las estadisticos básicos.
pd.notnull(data["body"]).values.ravel().sum()
# Out:
# 121

# %% [markdown]
# Los valores que faltan en un data set pueden venir por dos razones:
# * Extracción de los datos (problemas de ese dato a la hora de exportar csv, objetos incompatibles a la hora de generar fichero) - Lo lógico es mejorar proceso de generación csv
# * Recolección de los datos (no se ha podido recoger ese dato entre todas las personas, datos sensibles no contestados u opcionales)

# %% [markdown]
# ### Borrado de valores que faltan

# %%
# Borrado  que tienen NaN axis = 0 (filas) axis=1 (Columna) Ojo borraria toda la columna aunque hubiera 1.
# how = all todos los campos de la fila o columna es NaN. En este caso solo borra 1 fila cuyos campos no están informados
# y son todos NaN
data.dropna (axis=0,how="all")
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data2=data

# %%
#Ojo esta instrucción es menos restrictiva que la anterior ya que encuanto encuentre una fila con algún campo a NaN
#la borrara y en este caso nos quedaremos sin la mayoria de las filas.
data2.dropna(axis=0,how="any")
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %% [markdown]
# ### Computo de los valores faltantes

# %%
# Pasamos a rellenar los NaN con valores, bien sea 0 con string fijos o con datos promedio dependiendo del contexto

# %%
data3_sustituye_con_0 = data

# %%
data3_sustituye_con_0.fillna(0)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data4_sustituye_con_str = data

# %%
data4_sustituye_con_str = data4_sustituye_con_str.fillna("Desconocido")
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex          age  sibsp  parch  ticket     fare        cabin  \
# ...

# %%
# Es más habitual ir tratando columna a columna los NaN por que los se sustituyen por valores mas adecuados  a lo que representa la columna
data5 = data

# %%
data5["body"] = data5["body"].fillna(0)
data5["home.dest"] = data5["home.dest"].fillna("Desconocido")
data5.head(5)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    0.0
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    0.0
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    0.0
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    0.0
#
#                          home.dest
# ...

# %%
#Muy común es sustituir por valores promedio o media los NaN
pd.isnull(data5["age"]).values.ravel().sum()
# Out:
# 263

# %%
data5["age"].fillna(data5["age"].mean())
# Out:
# 0       29.000000
# 1        0.916700
# 2        2.000000
# 3       30.000000
# 4       25.000000
#           ...
# 1304    14.500000
# 1305    29.881135
# 1306    26.500000
# 1307    27.000000
# 1308    29.000000
# Name: age, Length: 1309, dtype: float64

# %%
#Rellenamos por el valor del campo inmediatamente hacia adelante o hacia atras de una fila dada
print (data5["age"][1290])
print (data5["age"][1291])
data5["age"].fillna(method="ffill")
# Out:
# 47.0
# nan
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305    14.5000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
#Rellenamos por el valor del campo inmediatamente hacia adelante o hacia atras de una fila dada
print (data5["age"][1291])
print (data5["age"][1294])
data5["age"].fillna(method="backfill")
# Out:
# nan
# 28.5
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305    26.5000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %% [markdown]
# ## Variables DUMMY

# %%
# relacionadas conn variables categoricas o que categorizan como la sexo
# Definimos tantas columnas como categorias haya.
# en el caso de sex una male y otra female

dummy_sex = pd.get_dummies(data["sex"], prefix="sex")

# %%
dummy_sex.tail()
# Out:
#       sex_female  sex_male
# 1304           1         0
# 1305           1         0
# 1306           0         1
# 1307           0         1
# 1308           0         1

# %%
data["sex"]
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
#Normalmnete una vez calculada las dummies:
# se borra la columna origen
# se añaden al dataset las dummies

data=data.drop(["sex"],axis=1)

# %%
data=pd.concat([data, dummy_sex], axis = 1)

# %%
data.head()
# Out:
#    pclass  survived                                             name      age  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  29.0000
# 1       1         1                   Allison, Master. Hudson Trevor   0.9167
# 2       1         0                     Allison, Miss. Helen Loraine   2.0000
# 3       1         0             Allison, Mr. Hudson Joshua Creighton  30.0000
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0      0      0   24160  211.3375       B5        S    2    0.0
# 1      1      2  113781  151.5500  C22 C26        S   11    0.0
# 2      1      2  113781  151.5500  C22 C26        S  NaN    0.0
# 3      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4      1      2  113781  151.5500  C22 C26        S  NaN    0.0
#
#                          home.dest  sex_female  sex_male
# ...

# %%
#FUNCIÓN QUE GENERA COLUMNAS DUMMIES Y ELIMINA LA ORIGINARIA QUE TENÍA LAS CATEGORIAS DONDE PARTES LAS DUMMIES.
def createDummies(df, var_name):
    dummy = pd.get_dummies(df[var_name], prefix=var_name)
    df = df.drop(var_name,axis=1)
    df = pd.concat([df, dummy], axis = 1)
    return df

# %%
data5.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    0.0
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    0.0
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    0.0
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    0.0
#
#                          home.dest
# ...

# %%
createDummies(data5,"sex")
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#           age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...
